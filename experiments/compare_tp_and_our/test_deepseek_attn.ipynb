# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent.parent))

from  lora_transfer_pruning.core.pruning_instrumentor import PruningInstrumentor
from transformers import AutoModelForCausalLM
import torch
import compare_utils
from compare_utils import debug_group_prune_step_by_step
from lora_transfer_pruning.adapter.torch_pruning.torch_pruning_group_builder import TorchPruningGroupBuilder
from compare_utils import full_attention_test_with_prune
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch.nn as nn
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).

# %%
# quantization_config = BitsAndBytesConfig(
#         load_in_4bit=True,
#         bnb_4bit_compute_dtype=torch.float16,  # Compute in float16 for speed
#         bnb_4bit_use_double_quant=True,  # Double quantization for extra memory savings
#         # Normalized float 4-bit (optimal for LLMs)
#         bnb_4bit_quant_type="nf4",
#         llm_int8_skip_modules=[
#             "lm_head",
#             "mlp.gate", #because DeepSeekV2ForCausalLM has a f.linear(self.gate.weight...) instead of self.gate()
#             #it couldn't be substituded with Linear4bit
#         ],
#     )

# %%
MODEL = "deepseek-ai/DeepSeek-V2-Lite-Chat" 
DTYPE = torch.float16
DEVICE = "cuda:0"


tokenizer = AutoTokenizer.from_pretrained(MODEL, trust_remote_code=False)
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

def load_model():
    model = AutoModelForCausalLM.from_pretrained(
        MODEL, trust_remote_code=False, device_map={"": DEVICE}, dtype=DTYPE,
        quantization_config=quantization_config, 
        attn_implementation="eager",
        
    )
    model.eval()
    router = model.model.layers[1].mlp.gate
    assert isinstance(router, nn.Linear), type(router)
    assert tuple(router.weight.shape) == (model.config.n_routed_experts, model.config.hidden_size)
    return model

# %%
model = load_model()
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model = load_model()
#
# Cell In[7], line 11, in load_model()
#      10 def load_model():
# ---> 11     model = AutoModelForCausalLM.from_pretrained(
#      12         MODEL, trust_remote_code=False, device_map={"": DEVICE}, dtype=DTYPE,
#      13         quantization_config=quantization_config,
#      14         attn_implementation="eager",
#      15
#      16     )
#      17     model.eval()
#      18     router = model.model.layers[1].mlp.gate
#
# File /glazkov-dev/LoRa-Transfer-Pruning/.venv/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:387, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     385     if model_class.config_class == config.sub_configs.get("text_config", None):
#     386         config = config.get_text_config()
# --> 387     return model_class.from_pretrained(
#     388         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     389     )
#     390 raise ValueError(
#     391     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     392     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     393 )
#
# File /glazkov-dev/LoRa-Transfer-Pruning/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:4135, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4118 # Finalize model weight initialization
#    4119 load_config = LoadStateDictConfig(
#    4120     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4121     ignore_mismatched_sizes=ignore_mismatched_sizes,
#    (...)
#    4133     download_kwargs=download_kwargs,
#    4134 )
# -> 4135 loading_info, disk_offload_index = cls._load_pretrained_model(model, state_dict, checkpoint_files, load_config)
#    4136 loading_info = cls._finalize_model_loading(model, load_config, loading_info)
#    4137 model.eval()  # Set model in evaluation mode to deactivate Dropout modules by default
#
# File /glazkov-dev/LoRa-Transfer-Pruning/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:4215, in PreTrainedModel._load_pretrained_model(model, state_dict, checkpoint_files, load_config, expected_keys)
#    4213 if load_config.device_map is not None and not is_hqq_or_quark:
#    4214     expanded_device_map = expand_device_map(load_config.device_map, expected_keys)
# -> 4215     caching_allocator_warmup(model, expanded_device_map, load_config.hf_quantizer)
#    4217 error_msgs = []
#    4219 if is_deepspeed_zero3_enabled() and not is_quantized:
#
# File /glazkov-dev/LoRa-Transfer-Pruning/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:4832, in caching_allocator_warmup(model, expanded_device_map, hf_quantizer)
#    4830     byte_count = min(byte_count, total_device_memory - 1.2 * 1024**3)
#    4831 # We divide by 2 here as we allocate in fp16
# -> 4832 _ = torch.empty(int(byte_count // 2), dtype=torch.float16, device=device, requires_grad=False)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 28.02 GiB. GPU 0 has a total capacity of 39.38 GiB of which 24.74 GiB is free. Process 1032660 has 2.14 GiB memory in use. Process 316270 has 12.07 GiB memory in use. Process 3080059 has 414.00 MiB memory in use. Of the allocated memory 0 bytes is allocated by PyTorch, and 0 bytes is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
from transformer_lens.model_bridge import TransformerBridge
import transformer_lens

bridge = TransformerBridge.boot_transformers(
    MODEL,
    hf_model=model,
    dtype=torch.float16,
)

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(MODEL)
validation_dataset = load_dataset(
    "Salesforce/wikitext",
    "wikitext-2-raw-v1",
    split="validation",
)
validation_dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 3760
# })

# %%
for i, text in enumerate(validation_dataset):
    print(f"{i}: {text}")
    if i > 10:
        break
# Out:
# 0: {'text': ''}
# 1: {'text': ' = Homarus gammarus = \n'}
# 2: {'text': ''}
# 3: {'text': ' Homarus gammarus , known as the European lobster or common lobster , is a species of clawed lobster from the eastern Atlantic Ocean , Mediterranean Sea and parts of the Black Sea . It is closely related to the American lobster , H. americanus . It may grow to a length of 60 cm ( 24 in ) and a mass of 6 kilograms ( 13 lb ) , and bears a conspicuous pair of claws . In life , the lobsters are blue , only becoming " lobster red " on cooking . Mating occurs in the summer , producing eggs which are carried by the females for up to a year before hatching into planktonic larvae . Homarus gammarus is a highly esteemed food , and is widely caught using lobster pots , mostly around the British Isles . \n'}
# 4: {'text': ''}
# 5: {'text': ' = = Description = = \n'}
# 6: {'text': ''}
# 7: {'text': ' Homarus gammarus is a large crustacean , with a body length up to 60 centimetres ( 24 in ) and weighing up to 5 – 6 kilograms ( 11 – 13 lb ) , although the lobsters caught in lobster pots are usually 23 – 38 cm ( 9 – 15 in ) long and weigh 0 @.@ 7 – 2 @.@ 2 kg ( 1 @.@ 5 – 4 @.@ 9 lb ) . Like other crustaceans , lobsters have a hard exoskeleton which they must shed in order to grow , in a process called ecdysis ( moulting ) . This may occur several times a year for young lobsters , but decreases to once every 1 – 2 years for larger animals . \n'}
# 8: {'text': ' The first pair of pereiopods is armed with a large , asymmetrical pair of claws . The larger one is the " crusher " , and has rounded nodules used for crushing prey ; the other is the " cutter " , which has sharp inner edges , and is used for holding or tearing the prey . Usually , the left claw is the crusher , and the right is the cutter . \n'}
# 9: {'text': ' The exoskeleton is generally blue above , with spots that coalesce , and yellow below . The red colour associated with lobsters only appears after cooking . This occurs because , in life , the red pigment astaxanthin is bound to a protein complex , but the complex is broken up by the heat of cooking , releasing the red pigment . \n'}
# 10: {'text': ' The closest relative of H. gammarus is the American lobster , Homarus americanus . The two species are very similar , and can be crossed artificially , although hybrids are unlikely to occur in the wild since their ranges do not overlap . The two species can be distinguished by a number of characteristics : \n'}
# 11: {'text': ' The rostrum of H. americanus bears one or more spines on the underside , which are lacking in H. gammarus . \n'}

# %%
CONTEXT_LENGTH = 256
NUM_EVAL_BLOCKS = 32 #(block=batch)
EVAL_BATCH_SIZE = 1

validation_text = "\n\n".join(
    text for text in validation_dataset["text"] if text.strip()
)
validation_tokens = tokenizer(
    validation_text,
    add_special_tokens=False,
    return_tensors="pt",
).input_ids[0]

num_blocks = NUM_EVAL_BLOCKS
assert num_blocks > 0, "Validation split does not contain enough tokens"
evaluation_blocks = validation_tokens[: num_blocks * CONTEXT_LENGTH].reshape(
    num_blocks, CONTEXT_LENGTH
)
evaluation_blocks.shape
# Out:
# torch.Size([32, 256])

# %%
# Fraction-based version of the activation-vs-structural comparison.
# Run on a freshly loaded, unpruned bridge; skip the preceding explicit-index
# comparison cell after restarting the kernel.
from compare_utils import compare_tp_and_transfer_pruning
from compare_utils import create_prune_task

FRACTION_ATTN_LAYERS = [0]
FRACTION_MLP_LAYERS = []
#ATTN_OUT_FRACTION = 0.1
#MLP_OUT_FRACTION = 0.3 
ATTN_OUT_FRACTION = [1, 2, 128+2]
MLP_OUT_FRACTION = [3, 5, 1000]
FRACTION_SEED = 0

prune_task = create_prune_task(FRACTION_ATTN_LAYERS, 
                               FRACTION_MLP_LAYERS, 
                               ATTN_OUT_FRACTION, 
                               MLP_OUT_FRACTION,
                               q_proj_name="q_proj")

# %%
# import importlib
# importlib.reload(compare_utils)

# %%
# bridge.blocks[0].attn._qk_head_dim

# %%
first_divergence, comparison_rows = full_attention_test_with_prune(bridge, 
                                                                   0, 
                                                                   evaluation_blocks, 
                                                                   prune_task,
                                                                   record_activations=True,
                                                                   one_token=False)
# Out:
# /glazkov-dev/LoRa-Transfer-Pruning/.venv/lib/python3.10/site-packages/torch_pruning/dependency/graph.py:390: UserWarning: Unwrapped parameters detected: ['model.layers.2._original_component.mlp._original_component.experts.down_proj', 'model.layers.0._original_component.post_attention_layernorm._original_component.weight', 'model.layers.2._original_component.input_layernorm._original_component.weight', 'model.layers.12._original_component.input_layernorm._original_component.weight', 'model.layers.11._original_component.mlp._original_component.experts.gate_up_proj', 'model.layers.17._original_component.mlp._original_component.experts.down_proj', 'model.layers.19._original_component.input_layernorm._original_component.weight', 'model.layers.22._original_component.mlp._original_component.experts.down_proj', 'model.layers.25._original_component.input_layernorm._original_component.weight', 'model.layers.10._original_component.input_layernorm._original_component.weight', 'model.layers.12._original_component.post_attention_layernorm._original_component.weight', 'model.layers.15._original_component.input_layernorm._original_component.weight', 'model.layers.15._original_component.post_attention_layernorm._original_component.weight', 'model.layers.19._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.19._original_component.mlp._original_component.experts.down_proj', 'model.layers.3._original_component.input_layernorm._original_component.weight', 'model.layers.8._original_component.mlp._original_component.experts.gate_up_proj', 'model.layers.10._original_component.mlp._original_component.experts.down_proj', 'model.layers.21._original_component.mlp._original_component.experts.gate_up_proj', 'model.layers.25._original_component.mlp._original_component.experts.gate_up_proj', 'model.layers.3._original_component.post_attention_layernorm._original_component.weight', 'model.layers.7._original_component.post_attention_layernorm._original_component.weight', 'model.layers.9._original_component.mlp._original_component.experts.down_proj', 'model.layers.12._original_component.mlp._original_component.experts.down_proj', 'model.layers.13._original_component.mlp._original_component.experts.down_proj', 'model.layers.20._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.20._original_component.mlp._original_component.experts.gate_up_proj', 'model.layers.17._original_component.mlp._original_component.experts.gate_up_proj', 'model.layers.7._original_component.input_layernorm._original_component.weight', 'model.layers.8._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.12._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.22._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.25._original_component.post_attention_layernorm._original_component.weight', 'model.layers.4._original_component.input_layernorm._original_component.weight', 'model.layers.5._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.7._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.23._original_component.post_attention_layernorm._original_component.weight', 'model.layers.25._original_component.mlp._original_component.experts.down_proj', 'model.layers.1._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.0._original_component.input_layernorm._original_component.weight', 'model.layers.1._original_component.mlp._original_component.experts.down_proj', 'model.layers.6._original_component.self_attn._original_component.kv_a_layernorm._original_component.weight', 'model.layers.16._original_component.post_attention_layernorm._original_component.weight', 'm ...
#  Torch-Pruning will prune the last non-singleton dimension of these parameters. If you wish to change this behavior, please provide an unwrapped_parameters argument.
#   warnings.warn(warning_str)
# module=blocks.0.attn.q_proj DeepSeek indices from group:
#   q_local=[1, 2, 130, 131]
#   q_nope=[1, 2]
#   q_rope=[2, 3]
#   kv_a.out=[514.0, 515.0]
#   kv_b.out=[1, 2, 257, 258, 513, 514, 769, 770, 1025, 1026, 1281, 1282, 1537, 1538, 1793, 1794, 2049, 2050, 2305, 2306, 2561, 2562, 2817, 2818, 3073, 3074, 3329, 3330, 3585, 3586, 3841, 3842]
#   kv_b.in=[]
#   o_proj.in=[]
# DeepSeek indices taken from corrected TP group:
#   q_local_idxs: count=4, idxs=[1, 2, 130, 131]
#   q_flat_idxs: count=64, idxs=[1, 2, 130, 131, 193, 194, 322, 323, 385, 386, 514, 515, 577, 578, 706, 707, 769, 770, 898, 899, 961, 962, 1090, 1091, 1153, 1154, 1282, 1283, 1345, 1346, 1474, 1475, 1537, 1538, 1666, 1667, 1729, 1730, 1858, 1859, 1921, 1922, 2050, 2051, 2113, 2114, 2242, 2243, 2305, 2306, 2434, 2435, 2497, 2498, 2626, 2627, 2689, 2690, 2818, 2819, 2881, 2882, 3010, 3011]
#   q_nope_local_idxs: count=2, idxs=[1, 2]
#   q_rope_local_idxs: count=2, idxs=[2, 3]
#   kv_a_out_idxs: count=2, idxs=[514, 515]
#   kv_b_out_idxs: count=32, idxs=[1, 2, 257, 258, 513, 514, 769, 770, 1025, 1026, 1281, 1282, 1537, 1538, 1793, 1794, 2049, 2050, 2305, 2306, 2561, 2562, 2817, 2818, 3073, 3074, 3329, 3330, 3585, 3586, 3841, 3842]
#   kv_b_in_idxs: count=0, idxs=[]
#   o_proj_in_idxs: count=0, idxs=[]
# [00] hook_in                          OK   shape=(1, 256, 2048) max=0.000e+00 mean=0.000e+00 rmse=0.000e+00 rel_l2=0.000e+00 abs_l2=0.000e+00
# [01] _original_component.q_proj.hook_in OK   shape=(1, 256, 2048) max=0.000e+00 mean=0.000e+00 rmse=0.000e+00 rel_l2=0.000e+00 abs_l2=0.000e+00
# [02] _original_component.q_proj.hook_out OK   shape=(1, 256, 3008) max=0.000e+00 mean=0.000e+00 rmse=0.000e+00 rel_l2=0.000e+00 abs_l2=0.000e+00 aligned=candidate.pruned_indices tensor([   1,    2,  130,  131,  193,  194,  322,  323,  385,  386,  514,  515,
#          577,  578,  706,  707,  769,  770,  898,  899,  961,  962, 1090, 1091,
#         1153, 1154, 1282, 1283, 1345, 1346, 1474, 1475, 1537, 1538, 1666, 1667,
#         1729, 1730, 1858, 1859, 1921, 1922, 2050, 2051, 2113, 2114, 2242, 2243,
#         2305, 2306, 2434, 2435, 2497, 2498, 2626, 2627, 2689, 2690, 2818, 2819,
#         2881, 2882, 3010, 3011]), dim=2
# [03] _original_component.kv_a_proj_with_mqa.hook_in OK   shape=(1, 256, 2048) max=0.000e+00 mean=0.000e+00 rmse=0.000e+00 rel_l2=0.000e+00 abs_l2=0.000e+00
# [04] _original_component.kv_a_proj_with_mqa.hook_out DIFF shape=(1, 256, 574) max=1.562e-02 mean=1.166e-04 rmse=4.308e-04 rel_l2=3.188e-04 abs_l2=1.652e-01 aligned=candidate.pruned_indices tensor([514, 515]), dim=2
# [05] _original_component.kv_a_layernorm.hook_in DIFF shape=(1, 256, 512) max=1.562e-02 mean=9.588e-05 rmse=3.022e-04 rel_l2=2.889e-04 abs_l2=1.094e-01
# [06] _original_component.kv_a_layernorm.hook_scale OK   shape=(1, 256, 1) max=6.348e-04 mean=6.012e-05 rmse=1.515e-04 rel_l2=1.448e-04 abs_l2=2.423e-03
# [07] _original_component.kv_a_layernorm.hook_normalized DIFF shape=(1, 256, 512) max=7.689e-03 mean=1.149e-04 rmse=2.714e-04 rel_l2=2.714e-04 abs_l2=9.826e-02
# [08] _original_component.kv_a_layernorm.hook_out DIFF shape=(1, 256, 512) max=5.859e-03 mean=1.238e-05 rmse=5.424e-05 rel_l2=4.607e-04 abs_l2=1.964e-02
# [09] hook_kv_latent                   DIFF shape=(1, 256, 512) max=5.859e-03 mean=1.238e-05 rmse=5.424e-05 rel_l2=4.607e-04 abs_l2=1.964e-02
# [10] _original_component.kv_b_proj.hook_in DIFF shape=(1, 256, 512) max=5.859e-03 mean=1.238e-05 rmse=5.424e-05 rel_l2=4.607e-04 abs_l2=1.964e-02
# [11] _original_component.kv_b_proj.hook_out DIFF shape=(1, 256, 4064) max=1.465e-03 mean=2.306e-05 rmse=5.097e-05 rel_l2=4.249e-04 abs_l2=5.198e-02 aligned=candidate.pruned_indices tensor([   1,    2,  257,  258,  513,  514,  769,  770, 1025, 1026, 1281, 1282,
#         1537, 1538, 1793, 1794, 2049, 2050, 2305, 2306, 2561, 2562, 2817, 2818,
#         3073, 3074, 3329, 3330, 3585, 3586, 3841, 3842]), dim=2
# [12] hook_rot_q                       OK   shape=(1, 256, 16, 62) max=0.000e+00 mean=0.000e+00 rmse=0.000e+00 rel_l2=0.000e+00 abs_l2=0.000e+00 aligned=candidate.pruned_indices tensor([2, 3]), dim=3
# [13] hook_rot_k                       DIFF shape=(1, 256, 1, 62) max=1.562e-02 mean=3.210e-04 rmse=1.013e-03 rel_l2=3.610e-04 abs_l2=1.276e-01 aligned=candidate.pruned_indices tensor([2, 3]), dim=3
# [14] hook_q                           OK   shape=(1, 16, 256, 188) max=0.000e+00 mean=0.000e+00 rmse=0.000e+00 rel_l2=0.000e+00 abs_l2=0.000e+00 aligned=candidate.pruned_indices tensor([  1,   2, 130, 131]), dim=3
# [15] hook_k                           DIFF shape=(1, 16, 256, 188) max=1.562e-02 mean=1.288e-04 rmse=5.844e-04 rel_l2=3.614e-04 abs_l2=5.128e-01 aligned=candidate.pruned_indices tensor([  1,   2, 130, 131]), dim=3
# [16] hook_v                           DIFF shape=(1, 16, 256, 128) max=9.766e-04 mean=1.199e-05 rmse=2.624e-05 rel_l2=4.300e-04 abs_l2=1.900e-02
# [17] hook_attn_scores                 DIFF shape=(1, 16, 256, 256) max=nan mean=nan rmse=nan rel_l2=nan abs_l2=nan
# [18] hook_pattern                     DIFF shape=(1, 16, 256, 256) max=3.418e-03 mean=4.732e-06 rmse=3.970e-05 rel_l2=1.875e-03 abs_l2=4.065e-02
# [19] _original_component.o_proj.hook_in DIFF shape=(1, 256, 2048) max=1.343e-03 mean=1.228e-05 rmse=2.931e-05 rel_l2=1.053e-03 abs_l2=2.122e-02
# [20] _original_component.o_proj.hook_out DIFF shape=(1, 256, 2048) max=9.766e-04 mean=2.189e-05 rmse=3.199e-05 rel_l2=7.491e-04 abs_l2=2.316e-02
# [21] hook_out                         DIFF shape=(1, 256, 2048) max=9.766e-04 mean=2.189e-05 rmse=3.199e-05 rel_l2=7.491e-04 abs_l2=2.316e-02
# [22] <model_output>                   DIFF shape=(1, 256, 102400) max=5.750e+00 mean=8.628e-02 rmse=1.634e-01 rel_l2=2.525e-02 abs_l2=8.368e+02
#
# FIRST DIVERGENCE: _original_component.kv_a_proj_with_mqa.hook_out

# %% [markdown]
# rot_q OK rot_q - diff because root_k depends on kv_a

# %%
# after correction of scaling inside attn with attn.hook_attn_scores
#values of hook_pattern
# до:    rel_l2 ≈ 8.48e-3
# после: rel_l2 ≈ 1.88e-3

# %% [markdown]
# Also checked with Codex kv_a when use zeroes obly in end of tensor and zeroes in whole tensor.
# It's problem of GEMM (that was in previous models too.)
#
# FP16 full-kept vs compact
#   max: 0.015625
#   mean: 0.00011660350719466805
#   rmse: 0.0004308477509766817
# FP32 full-kept vs compact
#   max: 0.0
#   mean: 0.0
#   rmse: 0.0
#
# The diff is for FP16 and zeroes position inside mult in GEMM.

# %%
bridge.blocks[0].attn.q_proj.weight.dtype
# Out:
# torch.float16

# %%
bridge.blocks[0].attn.qk_nope_head_dim
# Out:
# 126

# %%
row = next(
    row for row in comparison_rows
    if row["stage"] ==
    "_original_component.kv_a_proj_with_mqa.hook_out"
)

structural = row["reference_activation"]
masked_compact = row["candidate_activation"]
delta = structural.float() - masked_compact.float()

print("latent 0:512")
print("  max:", delta[..., :512].abs().max().item())
print("  mean:", delta[..., :512].abs().mean().item())
print("  different:", (delta[..., :512] != 0).sum().item())

print("kept RoPE 512:574")
print("  max:", delta[..., 512:].abs().max().item())
print("  mean:", delta[..., 512:].abs().mean().item())
print("  different:", (delta[..., 512:] != 0).sum().item())
# Out:
# latent 0:512
#   max: 0.015625
#   mean: 9.588059037923813e-05
#   different: 46903
# kept RoPE 512:574
#   max: 0.015625
#   mean: 0.0002877347869798541
#   different: 4440

# %% [markdown]
# Problems with GEMM probably, because latent space [..., :512] didn't prune. (DONE)
